# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.2/949.2 kB 31.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.91 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/107.7 GB disk)

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir RoadSignDetection

# %%
# !ls
# Out:
# RoadSignDetection

# %%
path = "/content/RoadSignDetection"

# %%
# %pwd
# Out:
# '/content'

# %%
import os
os.chdir(path)

# %%
# %pwd
# Out:
# '/content/RoadSignDetection'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ZM18kWrGYaTTHuu1Cxny")
project = rf.workspace("selfdriving-car-qtywx").project("self-driving-cars-lfjou")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Self-Driving-Cars-6 in yolov8:: 100%|██████████| 9950/9950 [00:02<00:00, 4957.20it/s]

# %%
import
os.chdir("/content/RoadSignDetection/Self-Driving-Cars-6/")

# %%
# %pwd
# Out:
# '/content/RoadSignDetection'

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/RoadSignDetection/Self-Driving-Cars-6/data.yaml epochs=10 imgsz=640 batch=16
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 102MB/s]
# Ultralytics 8.3.91 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !ls
# Out:
# runs  Self-Driving-Cars-6  yolov8n.pt

# %%
os.chdir("runs/detect/train")

# %%
# %pwd
# Out:
# '/content/RoadSignDetection/runs/detect/train'

# %%
# !ls
# Out:
# args.yaml					    PR_curve.png	   val_batch0_pred.jpg
# confusion_matrix_normalized.png			    R_curve.png		   val_batch1_labels.jpg
# confusion_matrix.png				    results.csv		   val_batch1_pred.jpg
# events.out.tfevents.1742063481.08d2d4680c92.6814.0  results.png		   val_batch2_labels.jpg
# F1_curve.png					    train_batch0.jpg	   val_batch2_pred.jpg
# labels_correlogram.jpg				    train_batch1.jpg	   weights
# labels.jpg					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg

# %%
# !pip install IPython

# %%
resultData = "/content/RoadSignDetection/runs/detect/train/"

from IPython.display import Image, display
Image(filename=f'{resultData}confusion_matrix.png')

# %%
Image(filename=f'{resultData}results.png')

# %%
import pandas as pd
df = pd.read_csv("/content/RoadSignDetection/runs/detect/train/results.csv")
print(df)
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1   3233.91         0.85968         4.04608         1.20041
# 1      2   6427.75         0.76510         2.97296         1.09264
# 2      3   9604.88         0.73472         2.32794         1.06005
# 3      4  12840.60         0.70831         1.75379         1.03667
# 4      5  16062.70         0.67313         1.41302         1.00919
# 5      6  19269.20         0.64037         1.16302         0.98594
# 6      7  22482.80         0.61649         0.99528         0.97907
# 7      8  25682.80         0.59679         0.88175         0.96495
# 8      9  28884.90         0.57443         0.81061         0.94766
# 9     10  32083.60         0.55761         0.75435         0.93911
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.21913            0.40596           0.26659
# 1               0.52553            0.46315           0.48365
# ...

# %%
# %pwd
# Out:
# '/content/RoadSignDetection/runs/detect/train'

# %%
os.chdir("/content")

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir CustomTestData

# %%
# !ls
# Out:
# CustomTestData	RoadSignDetection

# %%
os.chdir("/content/CustomTestData")

# %%
# %pwd
# Out:
# '/content/CustomTestData'

# %%
url = "https://drive.google.com/file/d/1VDYYaIMamThJiNyZm5N2jAPD3hDiBr_x/view?usp=sharing"
id = "1VDYYaIMamThJiNyZm5N2jAPD3hDiBr_x"

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1VDYYaIMamThJiNyZm5N2jAPD3hDiBr_x' -O data.mp4
# Out:
# --2025-03-16 04:04:52--  https://docs.google.com/uc?export=download&id=1VDYYaIMamThJiNyZm5N2jAPD3hDiBr_x
# Resolving docs.google.com (docs.google.com)... 74.125.142.102, 74.125.142.113, 74.125.142.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.142.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1VDYYaIMamThJiNyZm5N2jAPD3hDiBr_x&export=download [following]
# --2025-03-16 04:04:52--  https://drive.usercontent.google.com/download?id=1VDYYaIMamThJiNyZm5N2jAPD3hDiBr_x&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.142.132, 2607:f8b0:400e:c01::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.142.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11233808 (11M) [video/mp4]
# Saving to: ‘data.mp4’
#
# ...

# %%
weights_path = "/content/RoadSignDetection/runs/detect/train/weights/"

# !yolo task=detect mode=predict model={weights_path}best.pt conf=.25 source='data.mp4' save=True
# Out:
# Ultralytics 8.3.91 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 72 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/532) /content/CustomTestData/data.mp4: 384x640 (no detections), 161.7ms
# video 1/1 (frame 2/532) /content/CustomTestData/data.mp4: 384x640 (no detections), 142.1ms
# video 1/1 (frame 3/532) /content/CustomTestData/data.mp4: 384x640 (no detections), 158.7ms
# video 1/1 (frame 4/532) /content/CustomTestData/data.mp4: 384x640 (no detections), 133.1ms
# video 1/1 (frame 5/532) /content/CustomTestData/data.mp4: 384x640 (no detections), 146.0ms
# video 1/1 (frame 6/532) /content/CustomTestData/data.mp4: 384x640 (no detections), 136.1ms
# video 1/1 (frame 7/532) /content/CustomTestData/data.mp4: 384x640 (no detections), 132.5ms
# video 1/1 (frame 8/532) /content/CustomTestData/data.mp4: 384x640 (no detections), 133.5ms
# ...
